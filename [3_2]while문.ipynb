# %% [markdown]
# **while문 작성**

# %%
treehit=0 #나무를 찍은 횟수
while treehit<10:
  treehit+=1
  print("나무를 %d번 찍었습니다." %treehit)
  if treehit==10:
    print("나무 넘어갑니다.")
# Out:
# 나무를 1번 찍었습니다.
# 나무를 2번 찍었습니다.
# 나무를 3번 찍었습니다.
# 나무를 4번 찍었습니다.
# 나무를 5번 찍었습니다.
# 나무를 6번 찍었습니다.
# 나무를 7번 찍었습니다.
# 나무를 8번 찍었습니다.
# 나무를 9번 찍었습니다.
# 나무를 10번 찍었습니다.
# 나무 넘어갑니다.

# %%
num=0

prompt='''
1. Add
2. Del
3. List
4. Quit

Enter number: 
'''
while num!=4:
  print(prompt)
  num=int(input())
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
#
# 1
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
#
# 2
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
#
# 3
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
#
# 4

# %% [markdown]
# **while문 강제로 빠져나가기 : break**

# %%
coffee=10

while True:
  money=int(input("돈을 넣어 주세요: "))
  if money==300:
    print("커피를 줍니다.")
    coffee-=1
    print("남은 커피는 %d개 입니다."%coffee)
  elif money>300:
    print("거스름돈 %d를 주고 커피를 줍니다."%(money-300))
    coffee-=1
    print("남은 커피는 %d개 입니다."%coffee)
  else:
    print("돈을 다시 돌려주고 커피는 주지 않습니다.")
    print("남은 커피는 %d개 입니다."%coffee)
  if coffee==0:
    print("커피가 다 떨어졌습니다.")
    break
# Out:
# 돈을 넣어 주세요: 300
# 커피를 줍니다.
# 남은 커피는 9개 입니다.
# 돈을 넣어 주세요: 500
# 거스름돈 200를 주고 커피를 줍니다.
# 남은 커피는 8개 입니다.
# 돈을 넣어 주세요: 100
# 돈을 다시 돌려주고 커피는 주지 않습니다.
# 남은 커피는 8개 입니다.
# 돈을 넣어 주세요: 500
# 거스름돈 200를 주고 커피를 줍니다.
# 남은 커피는 7개 입니다.
# 돈을 넣어 주세요: 1000
# 거스름돈 700를 주고 커피를 줍니다.
# 남은 커피는 6개 입니다.
# 돈을 넣어 주세요: 3000
# 거스름돈 2700를 주고 커피를 줍니다.
# 남은 커피는 5개 입니다.
# 돈을 넣어 주세요: 100
# 돈을 다시 돌려주고 커피는 주지 않습니다.
# 남은 커피는 5개 입니다.
# 돈을 넣어 주세요: 7000
# 거스름돈 6700를 주고 커피를 줍니다.
# 남은 커피는 4개 입니다.
# 돈을 넣어 주세요: 400
# 거스름돈 100를 주고 커피를 줍니다.
# 남은 커피는 3개 입니다.
# 돈을 넣어 주세요: 500
# 거스름돈 200를 주고 커피를 줍니다.
# 남은 커피는 2개 입니다.
# 돈을 넣어 주세요: 7000
# 거스름돈 6700를 주고 커피를 줍니다.
# 남은 커피는 1개 입니다.
# 돈을 넣어 주세요: 1000
# 거스름돈 700를 주고 커피를 줍니다.
# 남은 커피는 0개 입니다.
# 커피가 다 떨어졌습니다.

# %% [markdown]
# **while문 맨 처음으로 돌아가기 : continue**

# %%
a=0
while a<10:
  a+=1
  if a%2==0:
    continue
  print(a)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#1부터 10까지의 숫자 중에 3의 배수를 뺀 수를 나머지 값을 출력

a=0
while a<10:
  a+=1
  if a%3==0:
    continue
  print(a)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8
# 10

# %% [markdown]
# **무한루프 : ctr + c**

# %%
while True:
  print("무한 루프")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# 무한 루프
# ...
